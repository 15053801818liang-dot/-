# %% [markdown]
# # 盘古战术面板 · 选项 B / C / D
#
# 前置：选项 A 心跳已通（`yushitai_audit.jsonl`）。
#
# 推荐 artifact（含 `structure_detail`）：
#
# ```python
# ARTIFACT = "workspace/artifacts/chanlun_btc_100k/chanlun_replay.json"
# ```
#
# 可视化需：`pip install matplotlib`

# %%
import sys
from pathlib import Path

ROOT = Path("..").resolve()
sys.path.insert(0, str(ROOT / "notebooks"))

from pangu_tactical import force_re_reason, plot_chanlun_structure, audit_and_visualize

ARTIFACT = "workspace/artifacts/chanlun_btc_100k/chanlun_replay.json"

# %% [markdown]
# ## 选项 B：策略纠错器

# %%
force_re_reason(
    ARTIFACT,
    "我认为此处背驰力度被高估了，请结合最近3根K线重新评估",
)

# %% [markdown]
# ## 选项 C：缠论语义透视

# %%
plot_chanlun_structure(ARTIFACT)

# %% [markdown]
# ## 选项 D：组合拳（纠错 → 可视化）

# %%
audit_and_visualize(
    ARTIFACT,
    "背驰点识别与中枢区间存在偏移，请重新映射",
)
